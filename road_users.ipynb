# %% [markdown]
# This notebook us used to score and evaluate Facilities for Vulnerable Road Users

# %%
import geopandas as gpd

# First to map out the Public transit access point design by scoring bus stops

geojson_file = "RoadUsers/Metro_Bus_Stops.geojson"
bus_stops_gdf = gpd.read_file(geojson_file)

# %%
import folium

shelter_stops = bus_stops_gdf[bus_stops_gdf["BSTP_SWK_OBS_TCD"] == "SHL"]

centroid = shelter_stops.geometry.unary_union.centroid
m = folium.Map(location=[centroid.y, centroid.x], zoom_start=14)

for _, stop in shelter_stops.iterrows():
    folium.CircleMarker(
        location=[stop.geometry.y, stop.geometry.x],
        radius=2,
        color="blue",
        fill=True,
        fill_color="blue",
        fill_opacity=0.7,
        tooltip=stop["BSTP_SWK_OBS_TCD"]  # Tooltip shows BSPD value
    ).add_to(m)

m
# Out:
# C:\Users\theod\AppData\Local\Temp\ipykernel_27896\851479277.py:5: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   centroid = shelter_stops.geometry.unary_union.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f36803f16e1231311d1deb4d5f0af79 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f36803f16e1231311d1deb4d5f0af79&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f36803f16e1231311d1deb4d5f0af79 = L.map(
#                 &quot;map_7f36803f16e1231311d1deb4d5f0af79&quot;,
#                 {
#                     center: [38.91066149174084, -77.02142625088469],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_338e11f717053efc63d71727bc2bab7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_338e11f717053efc63d71727bc2bab7b.addTo(map_7f36803f16e1231311d1deb4d5f0af79);
#
#
#             var circle_marker_59abe26e170092ae558fe7b5c769a4c2 = L.circleMarker(
#                 [38.918781789026404, -76.97116727581793],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7f36803f16e1231311d1deb4d5f0af79);
#
#
#             circle_marker_59abe26e170092ae558fe7b5c769a4c2.bindTooltip(
#                 `&lt;div&gt;
#                      SHL
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_5f3047ec1923abfd854162353d31449e = L.circleMarker(
#                 [38.87506076986357, -77.20940735261682],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7f36803f16e1231311d1deb4d5f0af79);
#
#
#             circle_marker_5f3047ec1923abfd854162353d31449e.bindTooltip(
#                 `&lt;div&gt;
#                      SHL
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_9e32ea57882aff3ca88eda77d43e1c7b = L.circleMarker(
#                 [38.90546379055452, -77.04081130226075],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7f36803f16e1231311d1deb4d5f0af79);
#
#
#             circle_marker_9e32ea57882aff3ca88eda77d43e1c7b.bindTooltip(
#                 `&lt;div&gt;
#                      SHL
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_3b3b717280e443006e55960813d0b02e = L.circleMarker(
#                 [38.91932178955833, -77.00068727963345],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_7f36803f16e1231311d1deb4d5f0af79);
#
#
#             circle_marker_3b3b717280e443006e55960813d0b02e.bindTooltip(
#                 `&lt;div&gt;
#                      SHL
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_519b3a19e1064fdea12c740786abb7cc = L.circleMarker(
#                 [38.89992078866672, -77.02147528720307],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;l

# %%
bus_stop_signs = bus_stops_gdf[
    (bus_stops_gdf["BSTP_PRK_RST_TCD"] == "NSG") &  # Condition for NSG
    (~bus_stops_gdf.index.isin(shelter_stops.index))  # Not in shelter_stops
]

centroid = bus_stop_signs.geometry.unary_union.centroid
m = folium.Map(location=[centroid.y, centroid.x], zoom_start=14)

for _, stop in bus_stop_signs.iterrows():
    folium.CircleMarker(
        location=[stop.geometry.y, stop.geometry.x],
        radius=2,
        color="blue",
        fill=True,
        fill_color="blue",
        fill_opacity=0.7,
    ).add_to(m)

m
# Out:
# C:\Users\theod\AppData\Local\Temp\ipykernel_27896\159228634.py:6: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   centroid = bus_stop_signs.geometry.unary_union.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a349144e1bec7898302c57d894df21a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a349144e1bec7898302c57d894df21a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a349144e1bec7898302c57d894df21a0 = L.map(
#                 &quot;map_a349144e1bec7898302c57d894df21a0&quot;,
#                 {
#                     center: [38.93077230267791, -77.0148631402179],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ee4068f288eda15dfd8a217bd52f052 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ee4068f288eda15dfd8a217bd52f052.addTo(map_a349144e1bec7898302c57d894df21a0);
#
#
#             var circle_marker_e80c5281bfeb0cf618ffec3db9a1461d = L.circleMarker(
#                 [38.72593875312679, -77.05627428606763],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a349144e1bec7898302c57d894df21a0);
#
#
#             var circle_marker_b054e39651c2e82eec62d27e210a3ccd = L.circleMarker(
#                 [38.80774476623858, -77.13196032404876],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a349144e1bec7898302c57d894df21a0);
#
#
#             var circle_marker_b35aa97e4fa929beaf34d5e134c3d0f2 = L.circleMarker(
#                 [38.8203487608242, -77.22147034727662],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a349144e1bec7898302c57d894df21a0);
#
#
#             var circle_marker_efdd9a964076cf63674226567cf12b04 = L.circleMarker(
#                 [38.82942076417481, -77.21097133973821],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a349144e1bec7898302c57d894df21a0);
#
#
#             var circle_marker_8617841ed0be42dbd461caf7bb89051e = L.circleMarker(
#                 [38.816660765536405, -77.21841735162907],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a349144e1bec7898302c57d894df21a0);
#
#
#             var circle_marker_2f981be51c31c5b18f5ecb21ebde8852 = L.circleMarker(
#                 [38.81745176321774, -77.2171353408933],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a349144e1bec7898302c57d894df21a0);
#
#
#             var ci

# %%
from folium.plugins import MarkerCluster

# All bus stops are Permanent

roads_clipped = gpd.read_file("roads_clipped.geojson")
roads_buffered = roads_clipped.copy()
roads_buffered["geometry"] = roads_buffered.geometry.buffer(0.0001)


shelter_stops_near_roads = shelter_stops[
    shelter_stops.geometry.apply(lambda x: roads_buffered.geometry.intersects(x).any())
]

bus_stop_signs_near_roads = bus_stop_signs[
    bus_stop_signs.geometry.apply(lambda x: roads_buffered.geometry.intersects(x).any())
]

centroid = roads_clipped.geometry.unary_union.centroid
m = folium.Map(location=[centroid.y, centroid.x], zoom_start=14)

# Add road segments to the map
for _, road in roads_clipped.iterrows():
    folium.GeoJson(road["geometry"], color="black", weight=2, tooltip="Road Segment").add_to(m)

    
for _, stop in bus_stop_signs_near_roads.iterrows():
    folium.CircleMarker(
        location=[stop.geometry.y, stop.geometry.x],
        radius=2,
        color="red",
        fill=True,
        fill_color="red",
        fill_opacity=0.7,
    ).add_to(m)

for _, stop in shelter_stops_near_roads.iterrows():
    folium.CircleMarker(
        location=[stop.geometry.y, stop.geometry.x],
        radius=2,
        color="blue",
        fill=True,
        fill_color="blue",
        fill_opacity=0.7,
    ).add_to(m)
m
# Out:
# C:\Users\theod\AppData\Local\Temp\ipykernel_27896\370209639.py:7: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   roads_buffered["geometry"] = roads_buffered.geometry.buffer(0.0001)
# C:\Users\theod\AppData\Local\Temp\ipykernel_27896\370209639.py:18: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   centroid = roads_clipped.geometry.unary_union.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e681a9c35227483c26a071a0ef6ce5a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e681a9c35227483c26a071a0ef6ce5a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e681a9c35227483c26a071a0ef6ce5a8 = L.map(
#                 &quot;map_e681a9c35227483c26a071a0ef6ce5a8&quot;,
#                 {
#                     center: [38.91444449709976, -77.07490647952284],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_172bfb59ff740c29ee4cf438eaa666a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_172bfb59ff740c29ee4cf438eaa666a9.addTo(map_e681a9c35227483c26a071a0ef6ce5a8);
#
#
#
#         function geo_json_1e0ddbda5de97076a7f76a6a01992fcc_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1e0ddbda5de97076a7f76a6a01992fcc = L.geoJson(null, {
#                 onEachFeature: geo_json_1e0ddbda5de97076a7f76a6a01992fcc_onEachFeature,
#
#             ...{
#   &quot;color&quot;: &quot;black&quot;,
#   &quot;weight&quot;: 2,
# }
#         });
#
#         function geo_json_1e0ddbda5de97076a7f76a6a01992fcc_add (data) {
#             geo_json_1e0ddbda5de97076a7f76a6a01992fcc
#                 .addData(data);
#         }
#             geo_json_1e0ddbda5de97076a7f76a6a01992fcc_add({&quot;coordinates&quot;: [[-77.0570472, 38.900448], [-77.05652799845517, 38.898965919066576]], &quot;type&quot;: &quot;LineString&quot;});
#         geo_json_1e0ddbda5de97076a7f76a6a01992fcc.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_1e0ddbda5de97076a7f76a6a01992fcc.bindTooltip(
#                 `&lt;div&gt;
#                      Road Segment
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             geo_json_1e0ddbda5de97076a7f76a6a01992fcc.addTo(map_e681a9c35227483c26a071a0ef6ce5a8);
#
#
#
#         function geo_json_3aed5d08838a3786d5eb9027088fe7cb_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3aed5d08838a3786d5eb9027088fe7cb = L.geoJson(null, {
#                 onEachFeature: geo_json_3aed5d08838a3786d5eb9027088fe7cb_onEachFeature,
#
#             ...{
#   &quot;color&quot;: &quot;black&quot;,
#   &quot;weight&quot;: 2,
# }
#         });
#
#         function geo_json_3aed5d08838a3786d5eb9027088fe7cb_add (data) {
#             geo_json_3aed5d08838a3786d5eb9027088fe7cb
#                 .addData(data);
#         }
#             geo_json_3aed5d08838a3786d5eb9027088fe7cb_add({&quot;coordinates&quot;: [[-77.05645713513769, 38.89903114315764], [-77.0568879, 38.9002904]], &quot;type&quot;: &quot;LineString&quot;});
#         geo_json_3aed5d08838a3786d5eb9027088fe7cb.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_3aed5d08838a3786d5eb9027088fe7cb.bindTooltip(
#                 `&lt;div&gt;
#                      Road Segment
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             geo_json_3aed5d08838a3786d5eb9027088fe7cb.addTo(map_e681a9c35227483c26a071a0ef6ce5a8);
#
#
#
#         function geo_json_ed689a837da8a7a62fa19ef13d20a882_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ed689a837da8a7a62fa19ef13d20a882 = L.geoJson(null, {
#                 onEachFeature: geo_json_ed689a837da8a7a62fa19ef13d20a882_onEachFeature,
#
#             ...{
#   &quot;color&quot;: &quot;black&quot;,
#   &quot;weight&quot;: 2,
# }
#         });
#
#         function geo_json_ed689a837da8a7a62fa19ef13d20a882_add (data) {
#             geo_json_ed689a837da8a7a62fa19ef13d20a882
#                 .addData(data);
#         }
#             geo_json_ed689a837da8a7a62fa19ef13d20a882_add({&quot;coordinates&quot;: [[-77.0568879, 38.9002904], [-77.0569835, 38.9005348]], &quot;type&quot;: &quot;LineString&quot;});
#         geo_json_ed689a837da8a7a62fa19ef13d20a882.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_ed689a837da8a7a62fa19ef13d20a882.bindTooltip(
#                 `&lt;div&gt;
#                      Road Segment
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             geo_json_ed689a837da8a7a62fa19ef13d20a882.addTo(map_e681a9c35227483c26a071a0ef6ce5a8);
#
#
#
#         function geo_json_67da369b5c1ec095f2c36b24892425ba_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_67da369b5c1ec095f2c36b24892425ba = L.geoJson(null, {
#                 onEachFeature: geo_json_67da369b5c1ec095f2c36b24892425ba_onEachFeature,

# %%
# For each road segment we need to count the number of bus stops that fall within a 0.0001 buffer to score accordingly
roads_clipped["buffer_geometry"] = roads_clipped.geometry.buffer(0.0001)

def count_nearby_stops(road_buffer, stops_gdf):
    return stops_gdf[stops_gdf.geometry.intersects(road_buffer)].shape[0]

roads_clipped["bus_stop_sign_count"] = roads_clipped["buffer_geometry"].apply(lambda buf: count_nearby_stops(buf, bus_stop_signs))
roads_clipped["shelter_stop_count"] = roads_clipped["buffer_geometry"].apply(lambda buf: count_nearby_stops(buf, shelter_stops))

roads_clipped["PUBLIC TRANSIT SCORE"] = None

for index, row in roads_clipped.iterrows():
    
    #Bus shelter present
    if row["shelter_stop_count"] > 0:
        roads_clipped.at[index, "PUBLIC TRANSIT SCORE"] = 0.75
    
    # Bus stop sign present
    elif row["bus_stop_sign_count"] > 0:
        roads_clipped.at[index, "PUBLIC TRANSIT SCORE"] = 0.5
        
    else: # No bus stops or bus shelters are present
        roads_clipped.at[index, "PUBLIC TRANSIT SCORE"] = 1

min_score = roads_clipped["PUBLIC TRANSIT SCORE"].min()
max_score = roads_clipped["PUBLIC TRANSIT SCORE"].max()

# Normalized to give a better visualization where from 0.5 : 1 becomes 0 to 1
roads_clipped["NORMALIZED_PUBLIC_TRANSIT_SCORE"] = (roads_clipped["PUBLIC TRANSIT SCORE"] - min_score) / (max_score - min_score)
# Out:
# C:\Users\theod\AppData\Local\Temp\ipykernel_27896\3037890473.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   roads_clipped["buffer_geometry"] = roads_clipped.geometry.buffer(0.0001)

# %%
import folium
from branca.colormap import linear

# Get the centroid of the road segments for initial map view
centroid = roads_clipped.geometry.unary_union.centroid

# Initialize folium map centered on the centroid
m = folium.Map(location=[centroid.y, centroid.x], zoom_start=14)

# Define a LinearColorMap for the scores
colormap = linear.RdBu_09.scale(0, 1)  # Blue to Red scale from 0 to 1

# Plot the roads with color based on their PUBLIC TRANSIT SCORE
for _, road in roads_clipped.iterrows():
    score = road["NORMALIZED_PUBLIC_TRANSIT_SCORE"]
    color = colormap(score)  # Get the color based on score
    
    # Plot the road with the color corresponding to its score
    folium.GeoJson(
        road['geometry'],
        style_function=lambda x, color=color: {
            'color': color,
            'weight': 3,
            'opacity': 0.7
        },
        tooltip=f"Score: {score:.2f}"
    ).add_to(m)
    
for _, stop in bus_stop_signs_near_roads.iterrows():
    folium.CircleMarker(
        location=[stop.geometry.y, stop.geometry.x],
        radius=2,
        color="black",
        fill=True,
        fill_color="red",
        fill_opacity=0.7,
    ).add_to(m)

for _, stop in shelter_stops_near_roads.iterrows():
    folium.CircleMarker(
        location=[stop.geometry.y, stop.geometry.x],
        radius=2,
        color="green",
        fill=True,
        fill_color="blue",
        fill_opacity=0.7,
    ).add_to(m)
# Add the colormap legend to the map
colormap.add_to(m)

# Show the map
m
# Out:
# C:\Users\theod\AppData\Local\Temp\ipykernel_27896\3481240935.py:5: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   centroid = roads_clipped.geometry.unary_union.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e6d813fafac86a06f0dd6a55b90cfa1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e6d813fafac86a06f0dd6a55b90cfa1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e6d813fafac86a06f0dd6a55b90cfa1 = L.map(
#                 &quot;map_1e6d813fafac86a06f0dd6a55b90cfa1&quot;,
#                 {
#                     center: [38.91444449709976, -77.07490647952284],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d90099141426d5ce67db0a4bdb447969 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d90099141426d5ce67db0a4bdb447969.addTo(map_1e6d813fafac86a06f0dd6a55b90cfa1);
#
#
#         function geo_json_0e125f0fd01390c01f5857b750bef2b2_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#2166acff&quot;, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_0e125f0fd01390c01f5857b750bef2b2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0e125f0fd01390c01f5857b750bef2b2 = L.geoJson(null, {
#                 onEachFeature: geo_json_0e125f0fd01390c01f5857b750bef2b2_onEachFeature,
#
#                 style: geo_json_0e125f0fd01390c01f5857b750bef2b2_styler,
#             ...{
# }
#         });
#
#         function geo_json_0e125f0fd01390c01f5857b750bef2b2_add (data) {
#             geo_json_0e125f0fd01390c01f5857b750bef2b2
#                 .addData(data);
#         }
#             geo_json_0e125f0fd01390c01f5857b750bef2b2_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-77.0570472, 38.900448], [-77.05652799845517, 38.898965919066576]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_0e125f0fd01390c01f5857b750bef2b2.bindTooltip(
#                 `&lt;div&gt;
#                      Score: 1.00
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             geo_json_0e125f0fd01390c01f5857b750bef2b2.addTo(map_1e6d813fafac86a06f0dd6a55b90cfa1);
#
#
#         function geo_json_bdd48f7fee32f1d5d04b250eeb23ab53_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#2166acff&quot;, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_bdd48f7fee32f1d5d04b250eeb23ab53_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_bdd48f7fee32f1d5d04b250eeb23ab53 = L.geoJson(null, {
#                 onEachFeature: geo_json_bdd48f7fee32f1d5d04b250eeb23ab53_onEachFeature,
#
#                 style: geo_json_bdd48f7fee32f1d5d04b250eeb23ab53_styler,
#             ...{
# }
#         });
#
#         function geo_json_bdd48f7fee32f1d5d04b250eeb23ab53_add (data) {
#             geo_json_bdd48f7fee32f1d5d04b250eeb23ab53
#                 .addData(data);
#         }
#             geo_json_bdd48f7fee32f1d5d04b250eeb23ab53_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-77.05645713513769, 38.89903114315764], [-77.0568879, 38.9002904]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#             geo_json_bdd48f7fee32f1d5d04b250eeb23ab53.bindTooltip(
#                 `&lt;div&gt;
#                      Score: 1.00
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             geo_json_bdd48f7fee32f1d5d04b250eeb23ab53.addTo(map_1e6d813fafac86a06f0dd6a55b90cfa1);
#
#
#         function geo_json_58aa19dc6e7fc8aa2db4a08e70a5a3fd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#2166acff&quot;, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_58aa19dc6e7fc8aa2db4a08e70a5a3fd_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_58aa19dc6e7fc8aa2db4a08e70a5a3fd = L.geoJson(null, {
#                 onEachFeature: geo_json_58aa19dc6e7fc8aa2db4a08e70a5a3fd_onEachFeature,
#
#                 style: geo_json_58aa19dc6e7fc8aa2db4a08e70a5a3fd_styler,
#             ...{
# }
#         });
#
#         function geo_json_58aa19dc6e7fc8aa2db4a08e70a5a3fd_add (data) {

# %% [markdown]
# Still need to identify locations of lay-by bus stops on the roadway

# %% [markdown]
# Continuing to Identify Cycling Infrastructure
